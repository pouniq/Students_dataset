# %%
import pandas as pd

# %%
df = pd.read_csv('center.csv')

# %%
['']
# Out:
#           name     sup  NChild  ETHSchool  Chores  mobile  laptop  sib
# 0        یاسین  father       1          4       2       0       0    0
# 1       علیرضا  father       2          3       3       1       0    1
# 2     محمدجواد  mother       1          3       3       1       0    0
# 3         مهدی    both       1          5       3       1       0    1
# 4        بردیا  father       1          4       3       0       1    1
# 5      امیرسام    both       1          1       2       1       0    0
# 6    امیرعلی پ    both       2          4       5       0       1    1
# 7     محمدحسین    both       2          5       3       1       0    1
# 8        اهورا  father       2          3       4       1       1    1
# 9         آرین  father       1          2       3       1       0    1
# 10       سبحان    both       2          5       4       0       1    1
# 11     بنیامین  father       2          3       4       0       0    1
# ...
